# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
inst=Image.open('datasets/coco_stuff/train_inst/000000203744.png')
label=Image.open('datasets/coco_stuff/train_label/000000203744.png')
img=Image.open('datasets/coco_stuff/train_img/000000203744.jpg')

# %%
inst.size
# Out:
# (640, 382)

# %%
label
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=640x382 at 0x7F27FE0FC9A0>

# %%
inst
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=640x382 at 0x7F27FC8E2880>

# %%
plt.imshow(img)

# %%
plt.imshow(np.array(img)[300:350, 250:360])

# %%
np.unique(np.array(label))
# Out:
# array([ 15, 119, 154, 255], dtype=uint8)

# %%
np.unique(np.array(inst))
# Out:
# array([  0,   1,   2,  15, 119, 154, 255], dtype=uint8)

# %%
np.unique(np.array(label)[300:350, 290:360])
# Out:
# array([ 15, 154, 255], dtype=uint8)

# %%
np.unique(np.array(inst)[300:350, 290:360])
# Out:
# array([  1,   2,  15, 154, 255], dtype=uint8)

# %%
plt.imshow(np.array(inst)[300:350, 290:360])
